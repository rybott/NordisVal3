# %% [markdown]
# # Docling

# %%
from docling.document_converter import DocumentConverter

source = "/home/coder/Repos/YIP/OCRing/data/2021.01 x9868.pdf" 
converter = DocumentConverter()
doc = converter.convert(source).document

print(doc.export_to_markdown())
# Out:
# 2025-09-14 02:57:56,262 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-14 02:57:56,263 - INFO - Going to convert document batch...
# 2025-09-14 02:57:56,263 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-09-14 02:57:56,263 - INFO - Accelerator device: 'cpu'
# 2025-09-14 02:57:57,282 - INFO - Accelerator device: 'cpu'
# 2025-09-14 02:57:57,529 - INFO - Accelerator device: 'cpu'
# 2025-09-14 02:57:57,677 - INFO - Processing document 2021.01 x9868.pdf
# 2025-09-14 02:58:05,700 - INFO - Finished converting document 2021.01 x9868.pdf in 9.44 sec.
# <!-- image -->
#
# 887-70-02-00 30265 0 C 001 30 S 66 002 CENTER FOR THE ADVANCEMENT OF SCIENCE IN SPACE INC 6905 N WICKHAM RD STE 500 MELBOURNE FL 3 2 9 4 0 - 7 5 5 3
#
# ## Your account statement
#
# For 01/29/2021
#
# ## BUSINESS INTEREST CHECKING 0000240239868
#
# ## Account summary
#
# | Your previousbalance as of12/31/2020        | $2,391,653.75   |
# ...

# %% [markdown]
# # With OCR

# %%
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions, EasyOcrOptions, TesseractCliOcrOptions

source = "/home/coder/Repos/Tax_Processing/Automating/Data/PDFs/2017 S Corp/111 S Corp Tax Return IS no Statements.pdf"
engine = "easyocr"   # or: "tesseract"

ocr_opts = EasyOcrOptions(lang=["en"]) if engine.lower()=="easyocr" else TesseractCliOcrOptions(lang=["eng"])

pipe = PdfPipelineOptions(do_ocr=True, ocr_options=ocr_opts)
conv = DocumentConverter(format_options={InputFormat.PDF: PdfFormatOption(pipeline_options=pipe)})

doc = conv.convert(source).document
print(doc.export_to_markdown())
print("test")
# Out:
# 2025-09-14 02:54:41,773 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-14 02:54:41,773 - INFO - Going to convert document batch...
# 2025-09-14 02:54:41,774 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 12264b5318c42ac4c254ce9f47fe4e57
# 2025-09-14 02:54:41,774 - INFO - Accelerator device: 'cpu'
# 2025-09-14 02:54:42,778 - INFO - Accelerator device: 'cpu'
# 2025-09-14 02:54:43,036 - INFO - Accelerator device: 'cpu'
# 2025-09-14 02:54:43,177 - INFO - Processing document 111 S Corp Tax Return IS no Statements.pdf
# 2025-09-14 02:54:43,990 - INFO - Finished converting document 111 S Corp Tax Return IS no Statements.pdf in 2.22 sec.
# test
